# %% [markdown]
# # Utilisation de numpy

# %%
import numpy as np

arr = np.array([1, 2, 3, 4])
resultat = arr * 2
print(resultat)   # [2 4 6 8]
# Out:
# [2 4 6 8]

# %% [markdown]
# # dimensions du tableau

# %%
arr.shape
# Out:
# (4,)

# %%
import numpy as np
arr2 = np.array([1, 2, 3,6 ,7,4])
resultat2 = arr2 * 2
print(resultat2)
# Out:
# [ 2  4  6 12 14  8]

# %% [markdown]
# # dimensions du tableau

# %%
arr2.shape
# Out:
# (6,)
